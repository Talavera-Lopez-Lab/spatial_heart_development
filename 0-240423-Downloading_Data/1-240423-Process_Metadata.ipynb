# %% [markdown]
# # Standardising the metadata tables
# [Cellxgene Datasets](https://cellxgene.cziscience.com/datasets)<br>
#
# CZ CELLxGENE Discover: A single-cell data platform for scalable exploration, analysis and modeling of aggregated data CZI Single-Cell Biology, et al. bioRxiv 2023.10.30; doi: https://doi.org/10.1101/2023.10.30.563174
# - Developed by: Christian Eger
# - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg
# - Created on: 2402423
# - Last modified: 240424

# %% [markdown]
# ## Environment
# **yaml path:** conda_environments/cellxgene-env.yml

# %% [markdown]
# ## Import modules

# %%
import sys
sys.path.append('../tools/')
import experiment

# %% [markdown]
# ## Load datasets

# %%
experiment_collection = experiment.Experiment_Collection(
    dataset_ids_csv='experiments.csv',
    h5ad_folder='../.data/h5ad_files/',
)
# Out:
# 100%|██████████| 79/79 [01:06<00:00,  1.20it/s]

# %% [markdown]
# ## Inspect metadata

# %% [markdown]
# ### Standardizing obs columns

# %% [markdown]
# #### Inspecting obs columns that aren't shared across all experiments

# %%
unique_obs_columns = experiment_collection.obs_difference.copy()
unique_obs_columns
# Out:
# ['AVN_P_cell',
#  'AVN_P_cell_abundance',
#  'AVN_bundle_cell',
#  'AVN_bundle_cell_abundance',
#  'Adip1',
#  'Adip1_abundance',
#  'Adip2',
#  'Adip2_abundance',
#  'Adip3',
#  'Adip3_abundance',
#  'Adip4',
#  'Adip4_abundance',
#  'Adipocyte',
#  'B',
#  'B_abundance',
#  'B_plasma',
#  'B_plasma_abundance',
#  'CD14+Mo',
#  'CD14+Mo_abundance',
#  'CD16+Mo',
#  'CD16+Mo_abundance',
#  'CD4+T_Tfh',
#  'CD4+T_Tfh_abundance',
#  'CD4+T_Th1',
#  'CD4+T_Th1_abundance',
#  'CD4+T_Th2',
#  'CD4+T_Th2_abundance',
#  'CD4+T_act',
#  'CD4+T_act_abundance',
#  'CD4+T_naive',
#  'CD4+T_naive_abundance',
#  'CD4+T_reg',
#  'CD4+T_reg_abundance',
#  'CD8+T_cytox',
#  'CD8+T_cytox_abundance',
#  'CD8+T_em',
#  'CD8+T_em_abundance',
#  'CD8+T_te',
#  'CD8+T_te_abundance',
#  'CD8+T_trans',
#  'CD8+T_trans_abundance',
#  'Cardiomyocyte',
#  'Cycling.cells',
#  'DC',
#  'DC_abundance',
#  'EC10_CMC-like',
#  'EC10_CMC-like_abundance',
#  'EC1_cap',
#  'EC1_cap_abundance',
#  'EC2_cap',
#  'EC2_cap_abundance',
#  'EC3_cap',
#  'EC3_cap_abundance',
#  'EC4_immune',
#  'EC4_immune_abundance',
#  'EC5_art',
#  'EC5_art_abundance',
#  'EC6_ven',
#  'EC6_ven_abundance',
#  'EC7_atria_abundance',
#  'EC7_endocardial',
#  'EC7_endocardial_abundance',
#  'EC8_ln',
#  'EC8_ln_abundance',
#  'EC9_FB-like',
#  'EC9_FB-like_abundance',
#  'Endothelial',
#  'FB1',
#  'FB1_abundance',
#  'FB2',
#  'FB2_abundance',
#  'FB3',
#  'FB3_abundance',
#  'FB4_abundance',
#  'FB4_activated',
#  'FB4_activated_abundance',
#  'FB5',
#  'FB5_abundance',
#  'FB6',
#  'FB6_abundance',
#  'Fibroblast',
#  'ILC',
#  'ILC_abundance',
#  'LYVE1+IGF1+MP',
#  'LYVE1+IGF1+MP_abundance',
#  'LYVE1+MP_cycling',
#  'LYVE1+MP_cycling_abundance',
#  'LYVE1+TIMD4+MP',
#  'LYVE1+TIMD4+MP_abundance',
#  'Lymphoid',
#  'MAIT-like',
#  'MAIT-like_abundance',
#  'Mast',
#  'Mast_abundance',
#  'Meso',
#  'Meso_abundance',
#  'MoMP',
#  'MoMP_abundance',
#  'Myeloid',
#  'NC1_abundance',
#  'NC1_glial',
#  'NC1_glial_abundance',
#  'NC2_abundance',
#  'NC2_glial_NGF+',
#  'NC2_glial_NGF+_abundance',
#  'NC3_glial',
#  'NC3_glial_abundance',
#  'NC5_glial',
#  'NC5_glial_abundance',
#  'NC6_schwann',
#  'NC6_schwann_abundance',
#  'NK_CD16hi',
#  'NK_CD16hi_abundance',
#  'NK_CD56hi',
#  'NK_CD56hi_abundance',
#  'Neuronal',
#  'Neut',
#  'Neut_abundance',
#  'PC1_vent',
#  'PC1_vent_abundance',
#  'PC2_atria',
#  'PC2_atria_abundance',
#  'PC3_str',
#  'PC3_str_abundance',
#  'PC4_CMC-like',
#  'PC4_CMC-like_abundance',
#  'Pericyte',
#  'Publication',
#  'SAN_P_cell',
#  'SAN_P_cell_abundance',
#  'SMC1_basic',
#  'SMC1_basic_abundance',
#  'SMC2_art',
#  'SMC2_art_abundance',
#  'T/NK_cycling',
#  'T/NK_cycling_abundance',
#  'aCM1',
#  'aCM1_abundance',
#  'aCM2',
#  'aCM2_abundance',
#  'aCM3',
#  'aCM3_abundance',
#  'aCM4',
#  'aCM4_abundance',
#  'aCM5',
#  'aCM5_abundance',
#  'age',
#  'annotation_JC',
#  'annotation_final',
#  'cell_type_original',
#  'donor_type',
#  'ethinic_origin',
#  'facility',
#  'flushed',
#  'gdT',
#  'gdT_abundance',
#  'in_tissue',
#  'log1p_n_genes_by_counts',
#  'log1p_total_counts',
#  'mt_frac',
#  'n_counts',
#  'n_genes',
#  'n_genes_by_counts',
#  'pct_counts_in_top_100_genes',
#  'pct_counts_in_top_200_genes',
#  'pct_counts_in_top_500_genes',
#  'pct_counts_in_top_50_genes',
#  'percent.mt',
#  'prop_Adip1',
#  'prop_Adip2',
#  'prop_B',
#  'prop_B_plasma',
#  'prop_CD14+Mo',
#  'prop_CD16+Mo',
#  'prop_CD4+T_act',
#  'prop_CD4+T_naive',
#  'prop_CD8+T_cytox',
#  'prop_CD8+T_em',
#  'prop_CD8+T_te',
#  'prop_CD8+T_trans',
#  'prop_DC',
#  'prop_EC10_CMC-like',
#  'prop_EC1_cap',
#  'prop_EC2_cap',
#  'prop_EC3_cap',
#  'prop_EC4_immune',
#  'prop_EC5_art',
#  'prop_EC6_ven',
#  'prop_EC7_endocardial',
#  'prop_EC8_ln',
#  'prop_FB1',
#  'prop_FB2',
#  'prop_FB3',
#  'prop_FB4_activated',
#  'prop_FB5',
#  'prop_FB6',
#  'prop_ILC',
#  'prop_LYVE1+IGF1+MP',
#  'prop_LYVE1+MP_cycling',
#  'prop_LYVE1+TIMD4+MP',
#  'prop_MAIT-like',
#  'prop_Mast',
#  'prop_MoMP',
#  'prop_NC1_glial',
#  'prop_NC2_glial_NGF+',
#  'prop_NK_CD16hi',
#  'prop_NK_CD56hi',
#  'prop_Neut',
#  'prop_PC2_atria',
#  'prop_PC3_str',
#  'prop_SAN_P_cell',
#  'prop_SMC1_basic',
#  'prop_SMC2_art',
#  'prop_aCM1',
#  'prop_aCM2',
#  'prop_aCM3',
#  'prop_aCM4',
#  'region',
#  'region_finest',
#  'sample',
#  'sangerID',
#  'total_counts',
#  'vCM1',
#  'vCM1_abundance',
#  'vCM2',
#  'vCM2_abundance',
#  'vCM3_stressed',
#  'vCM3_stressed_abundance',
#  'vCM4',
#  'vCM4_abundance',
#  'vCM5',
#  'vCM5_abundance',
#  'vSMCs']

# %%
# removing the columns relating to celltype
remove_columns_list = [
    'Adip',
    'CD4',
    'B_',
    'CD16',
    'vCM',
    'EC',
    'FB',
    'CD8',
    'CD14',
    'AVN',
    'DC',
    'Cardiomyocyte'
    'Cycling.cells',
    'Endothelial',
    'Fibroblast',
    'ILC',
    'Cycling.cells',
    'LYVE1',
    'Lymphoid',
    'MAIT',
    'Mast',
    'Meso',
    'MoMP',
    'Myeloid',
    'NC',
    'NK',
    'prop',
    'PC',
    'Pericyte',
    'SMC',
    'T/NK',
    'Neu',
    'SAN',
    'aCM',
    'vSMC',
    'gdT',
    'Cardiomyocyte',
    'B'
]

unique_obs_columns = [column for column in unique_obs_columns if not any(column.startswith(item) for item in remove_columns_list)]
unique_obs_columns
# Out:
# ['Publication',
#  'age',
#  'annotation_JC',
#  'annotation_final',
#  'cell_type_original',
#  'donor_type',
#  'ethinic_origin',
#  'facility',
#  'flushed',
#  'in_tissue',
#  'log1p_n_genes_by_counts',
#  'log1p_total_counts',
#  'mt_frac',
#  'n_counts',
#  'n_genes',
#  'n_genes_by_counts',
#  'pct_counts_in_top_100_genes',
#  'pct_counts_in_top_200_genes',
#  'pct_counts_in_top_500_genes',
#  'pct_counts_in_top_50_genes',
#  'percent.mt',
#  'region',
#  'region_finest',
#  'sample',
#  'sangerID',
#  'total_counts']

# %% [markdown]
# #### Creating dictionary for the purpose of standardizing column names

# %%
# The only two columns with different names referring to the same data appear to be 'total_counts' and 'n_counts'
standard_obs_columns_dict = {
    'n_counts': ['n_counts', 'total_counts']
}

# %%
experiment_collection.standardize_experiments_obs_columns_names(standard_obs_columns_dict)
# Out:
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts', 'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'total_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}
# {'n_counts': ['n_counts', 'total_counts']} {'n_counts': 'n_counts'}

# %% [markdown]
# ### Shared adata.obs columns across experiments

# %%
shared_obs_columns = experiment_collection.get_obs_intersection().copy()
shared_obs_columns
# Out:
# ['assay',
#  'assay_ontology_term_id',
#  'cell_type',
#  'cell_type_ontology_term_id',
#  'development_stage',
#  'development_stage_ontology_term_id',
#  'disease',
#  'disease_ontology_term_id',
#  'donor_id',
#  'is_primary_data',
#  'n_counts',
#  'observation_joinid',
#  'organism',
#  'organism_ontology_term_id',
#  'self_reported_ethnicity',
#  'self_reported_ethnicity_ontology_term_id',
#  'sex',
#  'sex_ontology_term_id',
#  'suspension_type',
#  'tissue',
#  'tissue_ontology_term_id',
#  'tissue_type']

# %% [markdown]
# ### Unique Values in shared adata.obs columns

# %%
# removing 'observation_joinid' and 'n_counts' because the columns values are not relevant
remove_columns = ['observation_joinid', 'n_counts']
shared_obs_columns = [column for column in shared_obs_columns if column not in remove_columns]
for column in shared_obs_columns:
    print(column, experiment_collection.get_obs_unique_values(column), '\n')
# Out:
# assay ['Visium Spatial Gene Expression']
#
# assay_ontology_term_id ['EFO:0010961']
#
# cell_type ['innate lymphoid cell', 'CD14-positive monocyte', 'glial cell', 'smooth muscle myoblast', 'adipocyte', 'unknown', 'cardiac pacemaker cell of sinoatrial node', 'mature NK T cell', 'endothelial cell', 'mast cell', 'CD8-positive, alpha-beta T cell', 'immature innate lymphoid cell', 'smooth muscle cell', 'smooth muscle cell of the pulmonary artery', 'vein endothelial cell', 'mucosal invariant T cell', 'neutrophil', 'endothelial cell of artery', 'CD8-positive, alpha-beta cytotoxic T cell', 'naive thymus-derived CD4-positive, alpha-beta T cell', 'dendritic cell, human', 'T-helper 2 cell', 'endothelial cell of lymphatic vessel', 'CD16-negative, CD56-bright natural killer cell, human', 'mesothelial cell', 'cardiac endothelial cell', 'lymphoid lineage restricted progenitor cell', 'endocardial cell', 'regular ventricular cardiac myocyte', 'pericyte', 'cardiac muscle myoblast', 'CD14-low, CD16-positive monocyte', 'neuronal receptor cell', 'monocyte', 'regular atrial cardiac myocyte', 'B cell', 'activated CD4-positive, alpha-beta T cell', 'macrophage', 'capillary endothelial cell', 'adipocyte of epicardial fat of left ventricle', 'atrioventricular bundle cell', 'fibroblast of cardiac tissue', 'plasma cell', 'CD16-positive, CD56-dim natural killer cell, human', 'effector memory CD8-positive, alpha-beta T cell']
#
# cell_type_ontology_term_id ['CL:1000477', 'CL:0002543', 'CL:1000413', 'CL:0000794', 'CL:0000896', 'CL:0000192', 'CL:0000895', 'CL:0000136', 'CL:0001054', 'CL:0000786', 'unknown', 'CL:0002350', 'CL:0010005', 'CL:0002548', 'CL:0000513', 'CL:0000097', 'CL:0000625', 'CL:0000814', 'CL:0000115', 'CL:0001056', 'CL:0000077', 'CL:0002396', 'CL:0000838', 'CL:0000006', 'CL:0000514', 'CL:0001065', 'CL:0002591', 'CL:0000938', 'CL:0000546', 'CL:0002138', 'CL:0000236', 'CL:0000235', 'CL:0000576', 'CL:0002131', 'CL:1000311', 'CL:0000939', 'CL:0010008', 'CL:0000775', 'CL:0000940', 'CL:0001082', 'CL:0000669', 'CL:0000125', 'CL:0000913', 'CL:0002129', 'CL:0002144']
#
# development_stage ['51-year-old human stage', 'fifth decade human stage', '52-year-old human stage', '44-year-old human stage', '58-year-old human stage', '57-year-old human stage', '40-year-old human stage', '63-year-old human stage', 'third decade human stage', '64-year-old human stage', '74-year-old human stage', 'eighth decade human stage', '47-year-old human stage', 'sixth decade human stage', 'seventh decade human stage', '43-year-old human stage', '66-year-old human stage', '60-year-old human stage', '55-year-old human stage', '61-year-old human stage', '38-year-old human stage']
#
# development_stage_ontology_term_id ['HsapDv:0000241', 'HsapDv:0000149', 'HsapDv:0000155', 'HsapDv:0000141', 'HsapDv:0000146', 'HsapDv:0000137', 'HsapDv:0000151', 'HsapDv:0000134', 'HsapDv:0000154', 'HsapDv:0000138', 'HsapDv:0000168', 'HsapDv:0000132', 'HsapDv:0000239', 'HsapDv:0000240', 'HsapDv:0000160', 'HsapDv:0000157', 'HsapDv:0000237', 'HsapDv:0000145', 'HsapDv:0000158', 'HsapDv:0000242', 'HsapDv:0000152']
#
# disease ['myocardial infarction', 'normal']
#
# disease_ontology_term_id ['MONDO:0005068', 'PATO:0000461']
#
# donor_id ['P16', 'P18', 'D6', 'P9', 'D5', 'P15', 'D3', 'P5', 'AV14', 'P8', 'P13', 'P6', 'P4', 'AV1', 'AH2', 'D8', 'A61', 'AH5', 'AH6', 'D7', 'P7', 'AH1', 'P19', 'P14', 'P2', 'P17', 'P11', 'P20', 'P10', 'P3', 'P1', 'P12']
#
# is_primary_data [False, True]
#
# organism ['Homo sapiens']
#
# organism_ontology_term_id ['NCBITaxon:9606']
#
# self_reported_ethnicity ['South Asian', 'European']
#
# self_reported_ethnicity_ontology_term_id ['HANCESTRO:0005', 'HANCESTRO:0006']
#
# sex ['male', 'female']
#
# sex_ontology_term_id ['PATO:0000383', 'PATO:0000384']
#
# suspension_type ['na']
#
# tissue ['apex of heart', 'sinoatrial node', 'heart right ventricle', 'right cardiac atrium', 'heart left ventricle', 'left cardiac atrium', 'interventricular septum', 'atrioventricular node']
#
# tissue_ontology_term_id ['UBERON:0002352', 'UBERON:0002078', 'UBERON:0002094', 'UBERON:0002351', 'UBERON:0002080', 'UBERON:0002079', 'UBERON:0002098', 'UBERON:0002084']
#
# tissue_type ['tissue']

# %%
'''
dict[str, dict[str, list[str]]]
{column_1: {new_column_value_1: [old_column_value_1_1, ..., old_column_value_1_n]}}
'''
obs_values_dict = {
    'cell_type': {
        'B Cell': ['B cell', ],
        'T Cell': ['T-helper 2 cell', 'activated CD4-positive, alpha-beta T cell', 'mucosal invariant T cell', 'naive thymus-derived CD4-positive, alpha-beta T cell',
                   'effector memory CD8-positive, alpha-beta T cell', 'CD8-positive, alpha-beta cytotoxic T cell', 'CD8-positive, alpha-beta T cell'],
        'NK Cell': ['CD16-negative, CD56-bright natural killer cell, human', 'CD16-positive, CD56-dim natural killer cell, human'],
        'NK T Cell': ['mature NK T cell', ],
        'Macrophage': ['macrophage', ],
        'Endothelial Cell': ['cardiac endothelial cell', 'capillary endothelial cell', 'endothelial cell of lymphatic vessel',
                             'endothelial cell of artery', 'endothelial cell', 'vein endothelial cell', ],
        'Fibroblast': ['fibroblast of cardiac tissue', ],
        'Monocyte': ['monocyte', 'CD14-positive monocyte', ],
        'Mesothelial Cell': ['mesothelial cell', ],
        'Pericyte': ['pericyte', ],
        'Dendritic Cell': ['dendritic cell, human', ],
        'Myoblast': [],
        'Plasma Cell': ['plasma cell', ],
        'ILC': ['innate lymphoid cell', 'immature innate lymphoid cell', ],
        'Glial Cell': ['glial cell'],
        'Monocyte': [],
        'Endocardial Cell': ['endocardial cell'],
        'Adipocyte': ['adipocyte of epicardial fat of left ventricle', 'adipocyte', ],
        'Smooth Muscle Cell': ['smooth muscle cell', ],
        'CLP': ['lymphoid lineage restricted progenitor cell', ],
        'Neutrophil': ['neutrophil', ],
        'Myocyte': ['regular ventricular cardiac myocyte', 'regular atrial cardiac myocyte'],
        'Myoblast': ['cardiac muscle myoblast', 'smooth muscle myoblast'],
        'Mast Cell': ['mast cell', ],
    },
    'development_stage': {
        '0-9s': [],
        '10-19': [],
        '20-29': [],
        '30-39': ['38-year-old human stage', 'third decade human stage', ],
        '40-49': ['47-year-old human stage', '44-year-old human stage','40-year-old human stage', '43-year-old human stage', ],
        '50-59': ['57-year-old human stage', '52-year-old human stage', 'fifth decade human stage', '51-year-old human stage', '58-year-old human stage',
                  '55-year-old human stage', ],
        '60-69': ['64-year-old human stage', '60-year-old human stage', '66-year-old human stage', 'sixth decade human stage', '61-year-old human stage',
                  '63-year-old human stage', ],
        '70-79': ['seventh decade human stage', '74-year-old human stage', ],
        '80-89': ['eighth decade human stage', ],
        '90-99': [],
        '100-109': [],
    }
}

# %%
experiment_collection.standardize_experiments_obs_columns_values(obs_values_dict)

# %%
shared_obs_columns = experiment_collection.get_obs_intersection().copy()
shared_obs_columns
# Out:
# ['assay',
#  'assay_ontology_term_id',
#  'cell_type',
#  'cell_type_ontology_term_id',
#  'cell_type_standard',
#  'development_stage',
#  'development_stage_ontology_term_id',
#  'development_stage_standard',
#  'disease',
#  'disease_ontology_term_id',
#  'donor_id',
#  'is_primary_data',
#  'n_counts',
#  'observation_joinid',
#  'organism',
#  'organism_ontology_term_id',
#  'self_reported_ethnicity',
#  'self_reported_ethnicity_ontology_term_id',
#  'sex',
#  'sex_ontology_term_id',
#  'suspension_type',
#  'tissue',
#  'tissue_ontology_term_id',
#  'tissue_type']

# %%
# removing 'observation_joinid' and 'n_counts' because the columns values are not relevant
remove_columns = ['observation_joinid', 'n_counts']
shared_obs_columns = [column for column in shared_obs_columns if column not in remove_columns]
for column in shared_obs_columns:
    print(column, experiment_collection.get_obs_unique_values(column), '\n')
# Out:
# assay ['Visium Spatial Gene Expression']
#
# assay_ontology_term_id ['EFO:0010961']
#
# cell_type ['innate lymphoid cell', 'CD14-positive monocyte', 'glial cell', 'smooth muscle myoblast', 'adipocyte', 'unknown', 'cardiac pacemaker cell of sinoatrial node', 'mature NK T cell', 'endothelial cell', 'mast cell', 'CD8-positive, alpha-beta T cell', 'immature innate lymphoid cell', 'smooth muscle cell', 'smooth muscle cell of the pulmonary artery', 'vein endothelial cell', 'mucosal invariant T cell', 'neutrophil', 'endothelial cell of artery', 'CD8-positive, alpha-beta cytotoxic T cell', 'naive thymus-derived CD4-positive, alpha-beta T cell', 'dendritic cell, human', 'T-helper 2 cell', 'endothelial cell of lymphatic vessel', 'CD16-negative, CD56-bright natural killer cell, human', 'mesothelial cell', 'cardiac endothelial cell', 'lymphoid lineage restricted progenitor cell', 'endocardial cell', 'regular ventricular cardiac myocyte', 'pericyte', 'cardiac muscle myoblast', 'CD14-low, CD16-positive monocyte', 'neuronal receptor cell', 'monocyte', 'regular atrial cardiac myocyte', 'B cell', 'activated CD4-positive, alpha-beta T cell', 'macrophage', 'capillary endothelial cell', 'adipocyte of epicardial fat of left ventricle', 'atrioventricular bundle cell', 'fibroblast of cardiac tissue', 'plasma cell', 'CD16-positive, CD56-dim natural killer cell, human', 'effector memory CD8-positive, alpha-beta T cell']
#
# cell_type_ontology_term_id ['CL:1000477', 'CL:0002543', 'CL:1000413', 'CL:0000794', 'CL:0000896', 'CL:0000192', 'CL:0000895', 'CL:0000136', 'CL:0001054', 'CL:0000786', 'unknown', 'CL:0002350', 'CL:0010005', 'CL:0002548', 'CL:0000513', 'CL:0000097', 'CL:0000625', 'CL:0000814', 'CL:0000115', 'CL:0001056', 'CL:0000077', 'CL:0002396', 'CL:0000838', 'CL:0000006', 'CL:0000514', 'CL:0001065', 'CL:0002591', 'CL:0000938', 'CL:0000546', 'CL:0002138', 'CL:0000236', 'CL:0000235', 'CL:0000576', 'CL:0002131', 'CL:1000311', 'CL:0000939', 'CL:0010008', 'CL:0000775', 'CL:0000940', 'CL:0001082', 'CL:0000669', 'CL:0000125', 'CL:0000913', 'CL:0002129', 'CL:0002144']
#
# cell_type_standard ['Mesothelial Cell', 'Smooth Muscle Cell', 'CD14-positive monocyte', 'Myocyte', 'Pericyte', 'Macrophage', 'Endothelial Cell', 'unknown', 'Glial Cell', 'cardiac pacemaker cell of sinoatrial node', 'Mast Cell', 'smooth muscle cell of the pulmonary artery', 'Plasma Cell', 'Fibroblast', 'NK Cell', 'CLP', 'B Cell', 'NK T Cell', 'Myoblast', 'ILC', 'T Cell', 'Endocardial Cell', 'CD14-low, CD16-positive monocyte', 'neuronal receptor cell', 'monocyte', 'atrioventricular bundle cell', 'Adipocyte', 'Dendritic Cell', 'Neutrophil']
#
# development_stage ['51-year-old human stage', 'fifth decade human stage', '52-year-old human stage', '44-year-old human stage', '58-year-old human stage', '57-year-old human stage', '40-year-old human stage', '63-year-old human stage', 'third decade human stage', '64-year-old human stage', '74-year-old human stage', 'eighth decade human stage', '47-year-old human stage', 'sixth decade human stage', 'seventh decade human stage', '43-year-old human stage', '66-year-old human stage', '60-year-old human stage', '55-year-old human stage', '61-year-old human stage', '38-year-old human stage']
#
# development_stage_ontology_term_id ['HsapDv:0000241', 'HsapDv:0000149', 'HsapDv:0000155', 'HsapDv:0000141', 'HsapDv:0000146', 'HsapDv:0000137', 'HsapDv:0000151', 'HsapDv:0000134', 'HsapDv:0000154', 'HsapDv:0000138', 'HsapDv:0000168', 'HsapDv:0000132', 'HsapDv:0000239', 'HsapDv:0000240', 'HsapDv:0000160', 'HsapDv:0000157', 'HsapDv:0000237', 'HsapDv:0000145', 'HsapDv:0000158', 'HsapDv:0000242', 'HsapDv:0000152']
#
# development_stage_standard ['60-69', '40-49', '70-79', '30-39', '50-59', '80-89']
#
# disease ['myocardial infarction', 'normal']
#
# disease_ontology_term_id ['MONDO:0005068', 'PATO:0000461']
#
# donor_id ['P16', 'P18', 'D6', 'P9', 'D5', 'P15', 'D3', 'P5', 'AV14', 'P8', 'P13', 'P6', 'P4', 'AV1', 'AH2', 'D8', 'A61', 'AH5', 'AH6', 'D7', 'P7', 'AH1', 'P19', 'P14', 'P2', 'P17', 'P11', 'P20', 'P10', 'P3', 'P1', 'P12']
#
# is_primary_data [False, True]
#
# organism ['Homo sapiens']
#
# organism_ontology_term_id ['NCBITaxon:9606']
#
# self_reported_ethnicity ['South Asian', 'European']
#
# self_reported_ethnicity_ontology_term_id ['HANCESTRO:0005', 'HANCESTRO:0006']
#
# sex ['male', 'female']
#
# sex_ontology_term_id ['PATO:0000383', 'PATO:0000384']
#
# suspension_type ['na']
#
# tissue ['apex of heart', 'sinoatrial node', 'heart right ventricle', 'right cardiac atrium', 'heart left ventricle', 'left cardiac atrium', 'interventricular septum', 'atrioventricular node']
#
# tissue_ontology_term_id ['UBERON:0002352', 'UBERON:0002078', 'UBERON:0002094', 'UBERON:0002351', 'UBERON:0002080', 'UBERON:0002079', 'UBERON:0002098', 'UBERON:0002084']
#
# tissue_type ['tissue']

# %%
columns_list = ['tissue', 'disease', 'organism', 'assay']

for column in columns_list:
    values_list = []
    for i in range(len(experiment_collection.experiments)):
        value = experiment_collection.experiments[i].adata.obs[column].unique()[0]
        values_list.append(value)
    experiment_collection.dataset_df[column] = values_list

# %%
experiment_collection.dataset_df
# Out:
#                                                      tissue  \
# dataset_id
# ffa80f3c-f779-49a2-9a7e-275089ece6e2          apex of heart
# ff9fbe4a-f353-4eff-9e3d-1edfde5179ac          apex of heart
# fdf7002a-97d0-4eea-9700-e7d325f074cb        sinoatrial node
# fca1bb0b-76c9-4422-84b7-c225e2c6a3e4  atrioventricular node
# f5dc5434-cd48-4389-a09c-7189dad6d0b1        sinoatrial node
# ...                                                     ...
# 570098e3-bfa4-49d0-ad51-40f79d185577   heart left ventricle
# 5480ae73-a12c-41ad-b10d-69a671502553   heart left ventricle
# 1f2871a8-3020-4ac4-8b36-fc09bcbb7885   heart left ventricle
# 1f196854-14e6-4446-9536-297b1f8d8852   heart left ventricle
# 1dcbb4d6-331b-4e78-ac10-e54aa821d355   heart left ventricle
#
#                                                     disease      organism  \
# dataset_id
# ffa80f3c-f779-49a2-9a7e-275089ece6e2                 normal  Homo sapiens
# ff9fbe4a-f353-4eff-9e3d-1edfde5179ac                 normal  Homo sapiens
# fdf7002a-97d0-4eea-9700-e7d325f074cb                 normal  Homo sapiens
# fca1bb0b-76c9-4422-84b7-c225e2c6a3e4                 normal  Homo sapiens
# f5dc5434-cd48-4389-a09c-7189dad6d0b1                 normal  Homo sapiens
# ...                                                     ...           ...
# 570098e3-bfa4-49d0-ad51-40f79d185577  myocardial infarction  Homo sapiens
# 5480ae73-a12c-41ad-b10d-69a671502553  myocardial infarction  Homo sapiens
# 1f2871a8-3020-4ac4-8b36-fc09bcbb7885  myocardial infarction  Homo sapiens
# 1f196854-14e6-4446-9536-297b1f8d8852  myocardial infarction  Homo sapiens
# 1dcbb4d6-331b-4e78-ac10-e54aa821d355  myocardial infarction  Homo sapiens
#
#                                                                assay
# dataset_id
# ffa80f3c-f779-49a2-9a7e-275089ece6e2  Visium Spatial Gene Expression
# ff9fbe4a-f353-4eff-9e3d-1edfde5179ac  Visium Spatial Gene Expression
# fdf7002a-97d0-4eea-9700-e7d325f074cb  Visium Spatial Gene Expression
# fca1bb0b-76c9-4422-84b7-c225e2c6a3e4  Visium Spatial Gene Expression
# f5dc5434-cd48-4389-a09c-7189dad6d0b1  Visium Spatial Gene Expression
# ...                                                              ...
# 570098e3-bfa4-49d0-ad51-40f79d185577  Visium Spatial Gene Expression
# 5480ae73-a12c-41ad-b10d-69a671502553  Visium Spatial Gene Expression
# 1f2871a8-3020-4ac4-8b36-fc09bcbb7885  Visium Spatial Gene Expression
# 1f196854-14e6-4446-9536-297b1f8d8852  Visium Spatial Gene Expression
# 1dcbb4d6-331b-4e78-ac10-e54aa821d355  Visium Spatial Gene Expression
#
# [79 rows x 4 columns]

# %%
experiment_collection.dataset_df.to_csv('experiments.csv')
